# %% [markdown]
# # Project Template - WBAI077-05
# ## Computational Methods in Neuroscience
#
# **Project:** [Project Number]
# **Dataset:** [Dataset Name]
# **Group Members:** [Names] or **Solo Work**
# **Date:** [Date]
#
# ---

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Set random seed for reproducibility
np.random.seed(42)

print("✓ Imports successful")

# %% [markdown]
# ## 2. Research Question
#
# **Research Question:**
# [Write your clear, specific research question here]
#
# **Hypothesis/Expected Outcome:**
# [What do you expect to find?]
#
# **Planned Analysis:**
# 1. [Step 1]
# 2. [Step 2]
# 3. [Step 3]

# %% [markdown]
# ## 3. Data Loading

# %%
# Define paths
data_dir = Path('../data')
figures_dir = Path('../figures')
figures_dir.mkdir(exist_ok=True)

# Load your data here
# Example for different data types:

# CSV data:
# data = pd.read_csv(data_dir / 'your_file.csv')

# MNE data (EEG/MEG):
# import mne
# raw = mne.io.read_raw_fif(data_dir / 'your_file.fif', preload=True)

# NIfTI data (fMRI):
# import nibabel as nib
# img = nib.load(data_dir / 'your_file.nii.gz')
# data = img.get_fdata()

print("✓ Data loaded")
# print(f"Data shape: {data.shape}")  # Uncomment and check!

# %% [markdown]
# ## 4. Data Exploration
#
# **Always plot your raw data first!**

# %%
# Explore data structure
# print(data.head())  # For pandas DataFrames
# print(data.shape)
# print(data.info())

# Basic statistics
# print(data.describe())

# %%
# Visualize raw data
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Example plots - adapt to your data!
# axes[0].plot(...)
# axes[0].set_xlabel('...')
# axes[0].set_ylabel('...')
# axes[0].set_title('Raw Data Overview')

# axes[1].hist(...)
# axes[1].set_xlabel('...')
# axes[1].set_ylabel('...')
# axes[1].set_title('Distribution')

plt.tight_layout()
plt.savefig(figures_dir / 'raw_data_overview.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Preprocessing
#
# **Document every preprocessing step clearly!**

# %%
# Example preprocessing steps
# - Filtering
# - Artifact removal
# - Normalization
# - Epoching (for time-series data)

print("✓ Preprocessing complete")

# %% [markdown]
# ## 6. Analysis
#
# **Break your analysis into logical sections**

# %% [markdown]
# ### 6.1 Analysis Step 1
# [Describe what you're doing]

# %%
# Your analysis code here

# %% [markdown]
# ### 6.2 Analysis Step 2
# [Describe what you're doing]

# %%
# Your analysis code here

# %% [markdown]
# ## 7. Results and Visualization
#
# **Create clear, publication-quality figures**

# %%
# Main results figure
fig, ax = plt.subplots(figsize=(12, 6))

# Your plotting code
# ax.plot(...)
# ax.set_xlabel('...', fontsize=12)
# ax.set_ylabel('...', fontsize=12)
# ax.set_title('Main Results', fontsize=14, fontweight='bold')
# ax.legend()
# ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(figures_dir / 'main_results.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Statistical Analysis (if applicable)

# %%
# Statistical tests
# from scipy import stats
# t_stat, p_value = stats.ttest_ind(group1, group2)
# print(f"t-statistic: {t_stat:.3f}, p-value: {p_value:.4f}")

# %% [markdown]
# ## 9. Summary and Interpretation
#
# **Key Findings:**
# 1. [Finding 1]
# 2. [Finding 2]
# 3. [Finding 3]
#
# **Interpretation:**
# [What do your results mean? How do they answer your research question?]
#
# **Limitations:**
# [What are the limitations of your analysis?]
#
# **Next Steps:**
# [What would you do if you had more time?]

# %% [markdown]
# ## 10. Export for Presentation/Report

# %%
# Save key results to file
# results_df.to_csv(figures_dir / 'results_summary.csv', index=False)

# List all saved figures
print("Saved figures:")
for fig_file in figures_dir.glob('*.png'):
    print(f"  - {fig_file.name}")
